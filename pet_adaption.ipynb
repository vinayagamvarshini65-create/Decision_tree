# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib

# %%
df = pd.read_csv(r"C:\Users\VARSHINI\Downloads\pet_adoption_data.csv")
df
# Out:
#       pet_id pet_type             breed  age_months   color    size  \
# 0        500     Bird          Parakeet         131  Orange   Large
# 1        501   Rabbit            Rabbit          73   White   Large
# 2        502      Dog  Golden Retriever         136  Orange  Medium
# 3        503     Bird          Parakeet          97   White   Small
# 4        504   Rabbit            Rabbit         123    Gray   Large
# ...      ...      ...               ...         ...     ...     ...
# 2002    2502      Dog            Poodle          72  Orange   Small
# 2003    2503   Rabbit            Rabbit         124   Brown   Small
# 2004    2504   Rabbit            Rabbit         113  Orange   Small
# 2005    2505      Dog          Labrador          12    Gray   Large
# 2006    2506   Rabbit            Rabbit         126   White  Medium
#
#       weight_kg  vaccinated  health_condition  timein_shelter_days  \
# 0      5.039768           1                 0                   27
# 1     16.086727           0                 0                    8
# 2      2.076286           0                 0                   85
# 3      3.339423           0                 0                   61
# 4     20.498100           0                 0                   28
# ...         ...         ...               ...                  ...
# 2002  27.039045           1                 0                   66
# 2003   4.726954           1                 1                   59
# 2004   1.758592           1                 0                   68
# 2005  20.961592           1                 0                   59
# 2006  18.519788           1                 0                   10
#
#       adoption_fee  previous_owner  adoption_likelihood
# 0              140               0                    0
# 1              235               0                    0
# 2              385               0                    0
# 3              217               1                    0
# 4               14               1                    0
# ...            ...             ...                  ...
# 2002            26               1                    1
# 2003           150               0                    0
# 2004           302               0                    0
# 2005           478               0                    0
# 2006           267               1                    0
#
# [2007 rows x 13 columns]

# %%
print(df.shape)
df.head()
# Out:
# (2007, 13)
#    pet_id pet_type             breed  age_months   color    size  weight_kg  \
# 0     500     Bird          Parakeet         131  Orange   Large   5.039768
# 1     501   Rabbit            Rabbit          73   White   Large  16.086727
# 2     502      Dog  Golden Retriever         136  Orange  Medium   2.076286
# 3     503     Bird          Parakeet          97   White   Small   3.339423
# 4     504   Rabbit            Rabbit         123    Gray   Large  20.498100
#
#    vaccinated  health_condition  timein_shelter_days  adoption_fee  \
# 0           1                 0                   27           140
# 1           0                 0                    8           235
# 2           0                 0                   85           385
# 3           0                 0                   61           217
# 4           0                 0                   28            14
#
#    previous_owner  adoption_likelihood
# 0               0                    0
# 1               0                    0
# 2               0                    0
# 3               1                    0
# 4               1                    0

# %%
df.drop(columns=['pet_id'], inplace=True)

# %%
df['adoption_likelihood'].value_counts().plot(kind='bar')
plt.title("Adoption Likelihood Distribution")
plt.xlabel("Adoption Likelihood")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(df['age_months'], bins=20)
plt.title("Age Distribution (Months)")
plt.xlabel("Age (Months)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(df['adoption_fee'], bins=20)
plt.title("Adoption Fee Distribution")
plt.xlabel("Adoption Fee")
plt.ylabel("Frequency")
plt.show()

# %%
df['size'] = df['size'].map({'Small': 1, 'Medium': 2, 'Large': 3})

# %%
df = pd.get_dummies(df, columns=['color', 'pet_type', 'breed'], drop_first=True)

# %%
df['weight_kg'] = MinMaxScaler().fit_transform(df[['weight_kg']])

# %%
df['adoption_fee'] = StandardScaler().fit_transform(df[['adoption_fee']])

# %%
minmax_scaler = MinMaxScaler()      
standard_scaler = StandardScaler()

# %%
minmax_scaler.fit(df[['weight_kg']])
standard_scaler.fit(df[['adoption_fee']])
# Out:
# StandardScaler()

# %%
df['weight_kg'] = minmax_scaler.transform(df[['weight_kg']])
df['adoption_fee'] = standard_scaler.transform(df[['adoption_fee']])

# %%
X = df.drop('adoption_likelihood', axis=1)
y = df['adoption_likelihood']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)

y_pred = dt.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8723051409618574
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91       405
#            1       0.81      0.80      0.81       198
#
#     accuracy                           0.87       603
#    macro avg       0.86      0.85      0.86       603
# weighted avg       0.87      0.87      0.87       603

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.title("Confusion Matrix - Default Decision Tree")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
plt.figure(figsize=(20,8))
plot_tree(dt, feature_names=X.columns, class_names=['Unlikely', 'Likely'], filled=True)
plt.show()

# %%
dt_tuned = DecisionTreeClassifier(
    criterion='entropy',
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=42
)

dt_tuned.fit(X_train, y_train)

y_pred_tuned = dt_tuned.predict(X_test)

print("Tuned Accuracy:", accuracy_score(y_test, y_pred_tuned))
print(classification_report(y_test, y_pred_tuned))
# Out:
# Tuned Accuracy: 0.8938640132669984
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92       405
#            1       0.81      0.88      0.84       198
#
#     accuracy                           0.89       603
#    macro avg       0.88      0.89      0.88       603
# weighted avg       0.90      0.89      0.89       603

# %%
cm_tuned = confusion_matrix(y_test, y_pred_tuned)
sns.heatmap(cm_tuned, annot=True, fmt='d')
plt.title("Confusion Matrix - Tuned Decision Tree")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
plt.figure(figsize=(20,8))
plot_tree(dt_tuned, feature_names=X.columns, class_names=['Unlikely', 'Likely'], filled=True)
plt.show()

# %%
joblib.dump(dt_tuned, "pet_adoption_decision_tree.pkl")

joblib.dump(minmax_scaler, "weight_scaler.pkl")
joblib.dump(standard_scaler, "adoption_fee_scaler.pkl")
# Out:
# ['adoption_fee_scaler.pkl']
